# %% [markdown]
# # 誤差理論與測量平差課程輔助程式
# ## 作者：黃明哲博士 (geodesy.cnu@gmail.com)
# #### ch01_01_azdis_Colab.ipynb
# #### 平面點基本定位方法 (方位角+距離)範例
#
# 本範例示範如何在Colab環境下，呼叫Git Hub上的pygeodadj Python程式庫
# pygeodadj是一個公開程式碼的大地測量平差Python套件，協助所有需要想要學習測量平差的人，從基礎的矩陣運算、最小二乘平差法並將其應用。
#
# 在Colab環境下，用下列指令將這個套件clone回來到Colab的虛擬機，即可呼叫其套件
#
# !git clone https://github.com/geodesy-CNU/pygeodadj.git
#
# <img src="https://drive.google.com/uc?id=1mys0_7935K8j162-G2Wb5pq8OWZXNA_Q">

# %%
# !git clone https://github.com/geodesy-CNU/pygeodadj.git
# !ls
# Out:
# Cloning into 'pygeodadj'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 56 (delta 16), reused 43 (delta 9), pack-reused 0
# Unpacking objects: 100% (56/56), done.
# pygeodadj  sample_data

# %%
# 測試範例
# %matplotlib inline

from pygeodadj.utils.adj_utils import azdis
from pygeodadj.utils.adj_utils import plot_azdis

# 觀測點
xa=2368.954
ya=1234.567

# 參考原方向
xb=3564.785
yb=5432.100;

# 呼叫計算方位角距離程式
deg,mm,sec,dis=azdis(xa,ya,xb,yb)

#顯示計算結果 
print("觀測點：\t%.3f %.3f"%(xa,ya))
print("參考點：\t%.3f %.3f"%(xb,yb))
print("距離:\t %.3fm"%(dis))
print("參考方位： %3.3d度 %2.2d分%.2f秒"%(deg,mm,sec))

plot_azdis(xa,ya,xb,yb,deg,mm,sec,dis)
# Out:
# 觀測點：	2368.954 1234.567
# 參考點：	3564.785 5432.100
# 距離:	 4364.550m
# 參考方位： 015度 54分6.01秒
